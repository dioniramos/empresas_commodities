# %%
# importations
import pandas as pd
import plotly.express as px

# Expand collumns
pd.set_option('display.max_columns', None)

# %%
# read the data
data = pd.read_excel('COMDINHEIRO_dionilramos942048626824.xlsx')

# %%
# vizualization of the data
display(data)
# Out:
#      Ticker Nome da Empresa                            Setor  \
# 0    AALR12          ALLIAR                            Saúde
# 1    AALR13          ALLIAR                            Saúde
# 2     AALR3          ALLIAR                            Saúde
# 3    ABCB11      ABC BRASIL                       Financeiro
# 4     ABCB3      ABC BRASIL                       Financeiro
# ..      ...             ...                              ...
# 995   OPCT3       OCEANPACT  Petróleo, Gás e Biocombustíveis
# 996  OPDC3B    BRAZILIAN FR                       Financeiro
# 997  OPDL3B     DALETH PART                Utilidade Pública
# 998   OPGM3       GAMA PART                           Outros
# 999  OPGM3B       GAMA PART                           Outros
#
#                                               SUBSETOR  \
# 0    Serviços Médico - Hospitalares, Análises e Dia...
# 1    Serviços Médico - Hospitalares, Análises e Dia...
# 2    Serviços Médico - Hospitalares, Análises e Dia...
# ...

# %%
data.dtypes
# Out:
# Ticker                                                object
# Nome da Empresa                                       object
# Setor                                                 object
# SUBSETOR                                              object
# SUBSUBSETOR                                           object
# Setor\nClassificação Comdinheiro                      object
# Volume Negociado\n                                   float64
# Preço de Fechamento                                  float64
# QUANT_ON_PN                                          float64
# QUANT_ON_PN_TESOURARIA                               float64
# Valor de Mercado\n\n                                 float64
# DY_60M                                               float64
# P/L                                                  float64
# PEG                                                  float64
# P/VPA                                                float64
# ...

# %%
# data cleaning negociated volume
data = data[data['Volume Negociado\n'] >= 100000]

# %%
# vizualization of the data
display(data)
# Out:
#     Ticker Nome da Empresa                            Setor  \
# 5    ABCB4      ABC BRASIL                       Financeiro
# 6    ABEV3       AMBEV S/A              Consumo não Cíclico
# 20   AERI3           AERIS                 Bens Industriais
# 34   AGRO3      BRASILAGRO              Consumo não Cíclico
# 35   AGXY3      AGROGALAXY              Consumo não Cíclico
# ..     ...             ...                              ...
# 988  OFSA3    OUROFINO S/A                            Saúde
# 991  OIBR3              OI                     Comunicações
# 992  OIBR4              OI                     Comunicações
# 994  ONCO3    ONCOCLINICAS                            Saúde
# 995  OPCT3       OCEANPACT  Petróleo, Gás e Biocombustíveis
#
#                                               SUBSETOR  \
# 5                           Intermediários Financeiros
# 6                                              Bebidas
# 20                             Máquinas e Equipamentos
# ...

# %%
# columns vizualization
data.columns
# Out:
# Index(['Ticker', 'Nome da Empresa', 'Setor', 'SUBSETOR', 'SUBSUBSETOR',
#        'Setor\nClassificação Comdinheiro', 'Volume Negociado\n',
#        'Preço de Fechamento', 'QUANT_ON_PN', 'QUANT_ON_PN_TESOURARIA',
#        'Valor de Mercado\n\n', 'DY_60M', 'P/L', 'PEG', 'P/VPA',
#        'Margem Bruta(%)', 'Margem Operacional(%)', 'Margem Ebitda(%)',
#        'Margem Líquida(%)', 'EBIT\n12 meses\n\n', 'EBITDA\n12 meses\n\n',
#        'Dívida Bruta\n', 'Dívida Líquida\n', 'DIVIDA_LIQUIDA/EBITDA',
#        'EV/EBITDA', 'EV', 'ROE', 'ROA', 'ROIC',
#        'Receita Líquida\n12 meses\n\n', 'LC', 'Lucro Líquido\n12 meses\n\n',
#        'LG', 'LS', 'LI', 'LPA', 'Fluxo de Caixa das Operações\n12 meses\n\n',
#        'Fluxo de Caixa dos Financiamentos\n12 meses\n\n',
#        'Fluxo de Caixa dos Financiamentos\n12 meses\n\n.1', 'consol_control',
#        'convencao', 'meses', 'data_demonstracao', 'data_analise'],
#       dtype='object')

# %%
# empresas unique coluna Setor
data['Setor'].unique()
# Out:
# array(['Financeiro', 'Consumo não Cíclico', 'Bens Industriais',
#        'Consumo Cíclico', 'Utilidade Pública', 'Materiais Básicos',
#        'Saúde', 'Tecnologia da Informação',
#        'Petróleo, Gás e Biocombustíveis', 'Comunicações'], dtype=object)

# %%
# filter data consumo_não_cíclico
consumo_nao_ciclico = data[data['Setor'] == 'Consumo não Cíclico']

# vizualization of the data
display(consumo_nao_ciclico)
# Out:
#     Ticker Nome da Empresa                Setor  \
# 6    ABEV3       AMBEV S/A  Consumo não Cíclico
# 34   AGRO3      BRASILAGRO  Consumo não Cíclico
# 35   AGXY3      AGROGALAXY  Consumo não Cíclico
# 91   ASAI3           ASSAI  Consumo não Cíclico
# 144  BEEF3         MINERVA  Consumo não Cíclico
# 241  BRFS3          BRF SA  Consumo não Cíclico
# 305  CAML3           CAMIL  Consumo não Cíclico
# 433  CRFB3    CARREFOUR BR  Consumo não Cíclico
# 686  GMAT3    GRUPO MATEUS  Consumo não Cíclico
# 789  JALL3    JALLESMACHAD  Consumo não Cíclico
# 794  JBSS3             JBS  Consumo não Cíclico
# 824  LAND3    TERRASANTAPA  Consumo não Cíclico
# 891  MDIA3    M.DIASBRANCO  Consumo não Cíclico
# 920  MNPR3         MINUPAR  Consumo não Cíclico
# 935  MRFG3         MARFRIG  Consumo não Cíclico
# 980  NTCO3    GRUPO NATURA  Consumo não Cíclico
#
#                                      SUBSETOR                  SUBSUBSETOR  \
# ...

# %%
# filter data petroleo_gas_biocombustiveis
petroleo_gas_biocombustiveis = data[data['Setor'] == 'Petróleo, Gás e Biocombustíveis']

# vizualization of the data
display(petroleo_gas_biocombustiveis)
# Out:
#     Ticker Nome da Empresa                            Setor  \
# 237  BRAV3           BRAVA  Petróleo, Gás e Biocombustíveis
# 450  CSAN3           COSAN  Petróleo, Gás e Biocombustíveis
# 995  OPCT3       OCEANPACT  Petróleo, Gás e Biocombustíveis
#
#                             SUBSETOR                        SUBSUBSETOR  \
# 237  Petróleo, Gás e Biocombustíveis  Exploração, Refino e Distribuição
# 450  Petróleo, Gás e Biocombustíveis  Exploração, Refino e Distribuição
# 995  Petróleo, Gás e Biocombustíveis            Equipamentos e Serviços
#
#     Setor\nClassificação Comdinheiro  Volume Negociado\n  Preço de Fechamento  \
# 237  Biocombustíveis, Gás e Petróleo         348448778.0                20.72
# 450            Alimentos Processados         192945564.0                 8.52
# 995  Biocombustíveis, Gás e Petróleo           2520905.0                 5.56
#
#       QUANT_ON_PN  QUANT_ON_PN_TESOURARIA  Valor de Mercado\n\n    DY_60M  \
# ...

# %%
# empresas unique coluna SUBSETOR
data['SUBSETOR'].unique()
# Out:
# array(['Intermediários Financeiros', 'Bebidas', 'Máquinas e Equipamentos',
#        'Agropecuária', 'Comércio Varejista', 'Exploração de Imóveis',
#        'Tecidos, Vestuário e Calçados', 'Serviços Diversos',
#        'Energia Elétrica', 'Água e Saneamento', 'Diversos',
#        'Comércio e Distribuição', 'Mineração', 'Construção e Engenharia',
#        'Transporte', 'Serviços Financeiros Diversos',
#        'Previdência e Seguros', 'Alimentos Processados',
#        'Medicamentos e Outros Produtos', 'Programas e Serviços',
#        'Petróleo, Gás e Biocombustíveis', 'Químicos', 'Telecomunicações',
#        'Gás', 'Siderurgia e Metalurgia', 'Construção Civil',
#        'Viagens e Lazer',
#        'Serviços Médico - Hospitalares, Análises e Diagnósticos',
#        'Madeira e Papel', 'Mídia', 'Material de Transporte', 'Comércio',
#        'Computadores e Equipamentos', 'Holdings Diversificadas',
#        'Automóveis e Motocicletas', 'Hoteis e Restaurantes',
# ...

# %%
# filter data Bebidas
bebidas = data[data['SUBSETOR'] == 'Bebidas']

# vizualization of the data
display(bebidas)
# Out:
#   Ticker Nome da Empresa                Setor SUBSETOR  \
# 6  ABEV3       AMBEV S/A  Consumo não Cíclico  Bebidas
#
#                 SUBSUBSETOR Setor\nClassificação Comdinheiro  \
# 6  Cervejas e Refrigerantes         Bens de Consumo e Varejo
#
#    Volume Negociado\n  Preço de Fechamento   QUANT_ON_PN  \
# 6        1.045013e+09                12.23  1.575766e+10
#
#    QUANT_ON_PN_TESOURARIA  Valor de Mercado\n\n     DY_60M        P/L  \
# 6              29482000.0          1.927161e+11  26.607522  13.403807
#
#         PEG     P/VPA  Margem Bruta(%)  Margem Operacional(%)  \
# 6  3.442043  1.945263        50.983424              24.119476
#
#    Margem Ebitda(%)  Margem Líquida(%)  EBIT\n12 meses\n\n  \
# 6         31.697377          17.414669        1.987601e+10
#
#    EBITDA\n12 meses\n\n  Dívida Bruta\n  Dívida Líquida\n  \
# 6          2.612069e+10    3.380273e+09     -1.755877e+10
#
#    DIVIDA_LIQUIDA/EBITDA  EV/EBITDA            EV        ROE      ROA  \
# ...

# %%
# filter data  Máquinas e Equipamentos
maquinase_e_equipamentos = data[data['SUBSETOR'] == 'Máquinas e Equipamentos']

# vizualization of the data
display(maquinase_e_equipamentos)
# Out:
#     Ticker Nome da Empresa             Setor                 SUBSETOR  \
# 20   AERI3           AERIS  Bens Industriais  Máquinas e Equipamentos
# 85   ARML3           ARMAC  Bens Industriais  Máquinas e Equipamentos
# 659  FRIO3       METALFRIO  Bens Industriais  Máquinas e Equipamentos
# 806  KEPL3    KEPLER WEBER  Bens Industriais  Máquinas e Equipamentos
# 907  MILS3           MILLS  Bens Industriais  Máquinas e Equipamentos
#
#                    SUBSUBSETOR Setor\nClassificação Comdinheiro  \
# 20   Máq. e Equip. Industriais      Indústria - Máqs. e Equips.
# 85   Máq. e Equip. Industriais                      Transportes
# 659  Máq. e Equip. Industriais                        Indústria
# 806  Máq. e Equip. Industriais      Indústria - Máqs. e Equips.
# 907  Máq. e Equip. Industriais             Construção e Imóveis
#
#      Volume Negociado\n  Preço de Fechamento  QUANT_ON_PN  \
# 20            6338174.0                 8.10   62120196.0
# ...

# %%
# filter data  Agropecuária
agropecuaria = data[data['SUBSETOR'] == 'Agropecuária']

# vizualization of the data
display(agropecuaria)
# Out:
#     Ticker Nome da Empresa                Setor      SUBSETOR  SUBSUBSETOR  \
# 34   AGRO3      BRASILAGRO  Consumo não Cíclico  Agropecuária  Agricultura
# 35   AGXY3      AGROGALAXY  Consumo não Cíclico  Agropecuária  Agricultura
# 824  LAND3    TERRASANTAPA  Consumo não Cíclico  Agropecuária  Agricultura
#
#     Setor\nClassificação Comdinheiro  Volume Negociado\n  Preço de Fechamento  \
# 34   Biocombustíveis, Gás e Petróleo           3614325.0                22.90
# 35                          Comércio            230841.0                 0.46
# 824                      Agronegócio            375378.0                13.25
#
#      QUANT_ON_PN  QUANT_ON_PN_TESOURARIA  Valor de Mercado\n\n     DY_60M  \
# 34   102683444.0                     0.0          2.351451e+09  58.315055
# 35   254543576.0               3395679.0          1.170900e+08  45.113240
# 824   96227000.0                 20000.0          1.275008e+09  12.425031
#
# ...

# %%
# filter data  Mineração
mineracao = data[data['SUBSETOR'] == 'Mineração']

# vizualization of the data
display(mineracao)
# Out:
#      Ticker Nome da Empresa              Setor   SUBSETOR         SUBSUBSETOR  \
# 99   AURA33        AURA 360  Materiais Básicos  Mineração  Minerais Metálicos
# 234   BRAP3       BRADESPAR  Materiais Básicos  Mineração  Minerais Metálicos
# 235   BRAP4       BRADESPAR  Materiais Básicos  Mineração  Minerais Metálicos
# 317   CBAV3             CBA  Materiais Básicos  Mineração  Minerais Metálicos
# 388   CMIN3    CSN MINERACA  Materiais Básicos  Mineração  Minerais Metálicos
#
#     Setor\nClassificação Comdinheiro  Volume Negociado\n  Preço de Fechamento  \
# 99                         Mineração          6469478.83                24.05
# 234                          Holding          1245143.00                16.03
# 235                          Holding         89837527.00                16.86
# 317                        Mineração         22246098.00                 4.95
# 388                        Mineração         43026982.00                 5.17
#
# ...

# %%
# filter data  Petróleo, Gás e Biocombustíveis
petroleo_gas_biocombustiveis = data[data['SUBSETOR'] == 'Petróleo, Gás e Biocombustíveis']

# vizualization of the data
display(petroleo_gas_biocombustiveis)
# Out:
#     Ticker Nome da Empresa                            Setor  \
# 237  BRAV3           BRAVA  Petróleo, Gás e Biocombustíveis
# 450  CSAN3           COSAN  Petróleo, Gás e Biocombustíveis
# 995  OPCT3       OCEANPACT  Petróleo, Gás e Biocombustíveis
#
#                             SUBSETOR                        SUBSUBSETOR  \
# 237  Petróleo, Gás e Biocombustíveis  Exploração, Refino e Distribuição
# 450  Petróleo, Gás e Biocombustíveis  Exploração, Refino e Distribuição
# 995  Petróleo, Gás e Biocombustíveis            Equipamentos e Serviços
#
#     Setor\nClassificação Comdinheiro  Volume Negociado\n  Preço de Fechamento  \
# 237  Biocombustíveis, Gás e Petróleo         348448778.0                20.72
# 450            Alimentos Processados         192945564.0                 8.52
# 995  Biocombustíveis, Gás e Petróleo           2520905.0                 5.56
#
#       QUANT_ON_PN  QUANT_ON_PN_TESOURARIA  Valor de Mercado\n\n    DY_60M  \
# ...

# %%
# filter data Siderurgia e Metalurgia
siderurgia_e_metalurgia = data[data['SUBSETOR'] == 'Siderurgia e Metalurgia']

# vizualization of the data
display(siderurgia_e_metalurgia)
# Out:
#     Ticker Nome da Empresa              Setor                 SUBSETOR  \
# 456  CSNA3    SID NACIONAL  Materiais Básicos  Siderurgia e Metalurgia
# 634  FESA4         FERBASA  Materiais Básicos  Siderurgia e Metalurgia
# 683  GGBR3          GERDAU  Materiais Básicos  Siderurgia e Metalurgia
# 684  GGBR4          GERDAU  Materiais Básicos  Siderurgia e Metalurgia
# 690  GOAU3      GERDAU MET  Materiais Básicos  Siderurgia e Metalurgia
# 691  GOAU4      GERDAU MET  Materiais Básicos  Siderurgia e Metalurgia
#
#     SUBSUBSETOR Setor\nClassificação Comdinheiro  Volume Negociado\n  \
# 456  Siderurgia          Metalurgia e Siderurgia         142420429.0
# 634  Siderurgia          Metalurgia e Siderurgia           6329851.0
# 683  Siderurgia          Metalurgia e Siderurgia           1517316.0
# 684  Siderurgia          Metalurgia e Siderurgia         532904025.0
# 690  Siderurgia          Metalurgia e Siderurgia            919922.0
# ...

# %%
# filter data Madeira e Papel
madeira_e_papel = data[data['SUBSETOR'] == 'Madeira e Papel']

# vizualization of the data
display(madeira_e_papel)
# Out:
#      Ticker Nome da Empresa              Setor         SUBSETOR  \
# 531   DXCO3           DEXCO  Materiais Básicos  Madeira e Papel
# 624   EUCA4         EUCATEX  Materiais Básicos  Madeira e Papel
# 811  KLBN11      KLABIN S/A  Materiais Básicos  Madeira e Papel
# 812   KLBN3      KLABIN S/A  Materiais Básicos  Madeira e Papel
# 813   KLBN4      KLABIN S/A  Materiais Básicos  Madeira e Papel
#
#           SUBSUBSETOR Setor\nClassificação Comdinheiro  Volume Negociado\n  \
# 531           Madeira        Celulose, Papel e Madeira          55711129.0
# 624           Madeira        Celulose, Papel e Madeira            603448.0
# 811  Papel e Celulose        Celulose, Papel e Madeira         379660753.0
# 812  Papel e Celulose        Celulose, Papel e Madeira           1514909.0
# 813  Papel e Celulose        Celulose, Papel e Madeira           4952924.0
#
#      Preço de Fechamento   QUANT_ON_PN  QUANT_ON_PN_TESOURARIA  \
# ...

# %%
# empresas unique coluna SUBSUBSETOR
data['SUBSUBSETOR'].unique()
# Out:
# array(['Bancos', 'Cervejas e Refrigerantes', 'Máq. e Equip. Industriais',
#        'Agricultura', 'Eletrodomésticos', 'Exploração de Imóveis',
#        'Calçados', 'Serviços Diversos', 'Energia Elétrica',
#        'Tecidos, Vestuário e Calçados', 'Água e Saneamento',
#        'Produtos Diversos', 'Serviços Educacionais', 'Alimentos',
#        'Minerais Metálicos', 'Construção Pesada',
#        'Linhas Aéreas de Passageiros', 'Serviços Financeiros Diversos',
#        'Seguradoras', 'Carnes e Derivados',
#        'Medicamentos e Outros Produtos', 'Programas e Serviços',
#        'Exploração, Refino e Distribuição', 'Petroquímicos',
#        'Telecomunicações', 'Alimentos Diversos', 'Exploração de Rodovias',
#        'Gás', 'Siderurgia', 'Incorporações', 'Viagens e Turismo',
#        'Serviços Médico - Hospitalares, Análises e Diagnósticos',
#        'Programas de Fidelização', 'Madeira', 'Publicidade e Propaganda',
#        'Material Aeronáutico e de Defesa', 'Material de Transporte',
# ...

# %%
# filter data Cervejas e Refrigerantes
cervejas_e_refrigerantes = data[data['SUBSUBSETOR'] == 'Cervejas e Refrigerantes']

# vizualization of the data
display(cervejas_e_refrigerantes)
# Out:
#   Ticker Nome da Empresa                Setor SUBSETOR  \
# 6  ABEV3       AMBEV S/A  Consumo não Cíclico  Bebidas
#
#                 SUBSUBSETOR Setor\nClassificação Comdinheiro  \
# 6  Cervejas e Refrigerantes         Bens de Consumo e Varejo
#
#    Volume Negociado\n  Preço de Fechamento   QUANT_ON_PN  \
# 6        1.045013e+09                12.23  1.575766e+10
#
#    QUANT_ON_PN_TESOURARIA  Valor de Mercado\n\n     DY_60M        P/L  \
# 6              29482000.0          1.927161e+11  26.607522  13.403807
#
#         PEG     P/VPA  Margem Bruta(%)  Margem Operacional(%)  \
# 6  3.442043  1.945263        50.983424              24.119476
#
#    Margem Ebitda(%)  Margem Líquida(%)  EBIT\n12 meses\n\n  \
# 6         31.697377          17.414669        1.987601e+10
#
#    EBITDA\n12 meses\n\n  Dívida Bruta\n  Dívida Líquida\n  \
# 6          2.612069e+10    3.380273e+09     -1.755877e+10
#
#    DIVIDA_LIQUIDA/EBITDA  EV/EBITDA            EV        ROE      ROA  \
# ...

# %%
# filter data Agricultura
agricultura = data[data['SUBSUBSETOR'] == 'Agricultura']

# vizualization of the data
display(agricultura)
# Out:
#     Ticker Nome da Empresa                Setor      SUBSETOR  SUBSUBSETOR  \
# 34   AGRO3      BRASILAGRO  Consumo não Cíclico  Agropecuária  Agricultura
# 35   AGXY3      AGROGALAXY  Consumo não Cíclico  Agropecuária  Agricultura
# 824  LAND3    TERRASANTAPA  Consumo não Cíclico  Agropecuária  Agricultura
#
#     Setor\nClassificação Comdinheiro  Volume Negociado\n  Preço de Fechamento  \
# 34   Biocombustíveis, Gás e Petróleo           3614325.0                22.90
# 35                          Comércio            230841.0                 0.46
# 824                      Agronegócio            375378.0                13.25
#
#      QUANT_ON_PN  QUANT_ON_PN_TESOURARIA  Valor de Mercado\n\n     DY_60M  \
# 34   102683444.0                     0.0          2.351451e+09  58.315055
# 35   254543576.0               3395679.0          1.170900e+08  45.113240
# 824   96227000.0                 20000.0          1.275008e+09  12.425031
#
# ...

# %%
# filter data Alimentos
alimentos = data[data['SUBSUBSETOR'] == 'Alimentos']

# vizualization of the data
display(alimentos)
# Out:
#     Ticker Nome da Empresa                Setor                 SUBSETOR  \
# 91   ASAI3           ASSAI  Consumo não Cíclico  Comércio e Distribuição
# 433  CRFB3    CARREFOUR BR  Consumo não Cíclico  Comércio e Distribuição
# 686  GMAT3    GRUPO MATEUS  Consumo não Cíclico  Comércio e Distribuição
#
#     SUBSUBSETOR Setor\nClassificação Comdinheiro  Volume Negociado\n  \
# 91    Alimentos         Bens de Consumo e Varejo         261338608.0
# 433   Alimentos                         Comércio         135012774.0
# 686   Alimentos         Bens de Consumo e Varejo          58535075.0
#
#      Preço de Fechamento   QUANT_ON_PN  QUANT_ON_PN_TESOURARIA  \
# 91                  5.77  1.352090e+09                     0.0
# 433                 5.91  2.109057e+09                     0.0
# 686                 6.98  2.209091e+09                254947.0
#
#      Valor de Mercado\n\n     DY_60M        P/L        PEG     P/VPA  \
# ...

# %%
# filter data Minerais Metálicos
minerais_metalicos = data[data['SUBSUBSETOR'] == 'Minerais Metálicos']

# vizualization of the data
display(minerais_metalicos)
# Out:
#      Ticker Nome da Empresa              Setor   SUBSETOR         SUBSUBSETOR  \
# 99   AURA33        AURA 360  Materiais Básicos  Mineração  Minerais Metálicos
# 234   BRAP3       BRADESPAR  Materiais Básicos  Mineração  Minerais Metálicos
# 235   BRAP4       BRADESPAR  Materiais Básicos  Mineração  Minerais Metálicos
# 317   CBAV3             CBA  Materiais Básicos  Mineração  Minerais Metálicos
# 388   CMIN3    CSN MINERACA  Materiais Básicos  Mineração  Minerais Metálicos
#
#     Setor\nClassificação Comdinheiro  Volume Negociado\n  Preço de Fechamento  \
# 99                         Mineração          6469478.83                24.05
# 234                          Holding          1245143.00                16.03
# 235                          Holding         89837527.00                16.86
# 317                        Mineração         22246098.00                 4.95
# 388                        Mineração         43026982.00                 5.17
#
# ...

# %%
# filter data Carnes e Derivados
carnes_e_derivados = data[data['SUBSUBSETOR'] == 'Carnes e Derivados']

# vizualization of the data
display(carnes_e_derivados)
# Out:
#     Ticker Nome da Empresa                Setor               SUBSETOR  \
# 144  BEEF3         MINERVA  Consumo não Cíclico  Alimentos Processados
# 241  BRFS3          BRF SA  Consumo não Cíclico  Alimentos Processados
# 794  JBSS3             JBS  Consumo não Cíclico  Alimentos Processados
# 920  MNPR3         MINUPAR  Consumo não Cíclico  Alimentos Processados
# 935  MRFG3         MARFRIG  Consumo não Cíclico  Alimentos Processados
#
#             SUBSUBSETOR Setor\nClassificação Comdinheiro  Volume Negociado\n  \
# 144  Carnes e Derivados            Alimentos Processados          43960242.0
# 241  Carnes e Derivados            Alimentos Processados         471065660.0
# 794  Carnes e Derivados            Alimentos Processados         557423765.0
# 920  Carnes e Derivados            Alimentos Processados            125590.0
# 935  Carnes e Derivados            Alimentos Processados         401370759.0
#
#      Preço de Fechamento   QUANT_ON_PN  QUANT_ON_PN_TESOURARIA  \
# ...

# %%
# filter data Petroquímicos
petroquimicos = data[data['SUBSUBSETOR'] == 'Petroquímicos']

# vizualization of the data
display(petroquimicos)
# Out:
#     Ticker Nome da Empresa              Setor  SUBSETOR    SUBSUBSETOR  \
# 255  BRKM3         BRASKEM  Materiais Básicos  Químicos  Petroquímicos
# 256  BRKM5         BRASKEM  Materiais Básicos  Químicos  Petroquímicos
# 500  DEXP3      DEXXOS PAR  Materiais Básicos  Químicos  Petroquímicos
#
#     Setor\nClassificação Comdinheiro  Volume Negociado\n  Preço de Fechamento  \
# 255                     Petroquímico            187461.0                12.80
# 256                     Petroquímico          47656027.0                12.19
# 500                          Holding            687765.0                 8.50
#
#      QUANT_ON_PN  QUANT_ON_PN_TESOURARIA  Valor de Mercado\n\n     DY_60M  \
# 255  797207807.0                    27.0          9.993481e+09  72.151544
# 256  797207807.0                    27.0          9.993481e+09  75.762081
# 500  109310638.0                361360.0          9.291404e+08  18.914700
#
# ...

# %%
# filter data Siderurgia
siderurgia = data[data['SUBSUBSETOR'] == 'Siderurgia']

# vizualization of the data
display(siderurgia)
# Out:
#     Ticker Nome da Empresa              Setor                 SUBSETOR  \
# 456  CSNA3    SID NACIONAL  Materiais Básicos  Siderurgia e Metalurgia
# 634  FESA4         FERBASA  Materiais Básicos  Siderurgia e Metalurgia
# 683  GGBR3          GERDAU  Materiais Básicos  Siderurgia e Metalurgia
# 684  GGBR4          GERDAU  Materiais Básicos  Siderurgia e Metalurgia
# 690  GOAU3      GERDAU MET  Materiais Básicos  Siderurgia e Metalurgia
# 691  GOAU4      GERDAU MET  Materiais Básicos  Siderurgia e Metalurgia
#
#     SUBSUBSETOR Setor\nClassificação Comdinheiro  Volume Negociado\n  \
# 456  Siderurgia          Metalurgia e Siderurgia         142420429.0
# 634  Siderurgia          Metalurgia e Siderurgia           6329851.0
# 683  Siderurgia          Metalurgia e Siderurgia           1517316.0
# 684  Siderurgia          Metalurgia e Siderurgia         532904025.0
# 690  Siderurgia          Metalurgia e Siderurgia            919922.0
# ...

# %%
# filter data Madeira
madeira = data[data['SUBSUBSETOR'] == 'Madeira']

# vizualization of the data
display(madeira)
# Out:
#     Ticker Nome da Empresa              Setor         SUBSETOR SUBSUBSETOR  \
# 531  DXCO3           DEXCO  Materiais Básicos  Madeira e Papel     Madeira
# 624  EUCA4         EUCATEX  Materiais Básicos  Madeira e Papel     Madeira
#
#     Setor\nClassificação Comdinheiro  Volume Negociado\n  Preço de Fechamento  \
# 531        Celulose, Papel e Madeira          55711129.0                 6.27
# 624        Celulose, Papel e Madeira            603448.0                13.56
#
#      QUANT_ON_PN  QUANT_ON_PN_TESOURARIA  Valor de Mercado\n\n     DY_60M  \
# 531  820566000.0              12202000.0          5.144949e+09  37.377395
# 624   92619000.0                479000.0          1.354064e+09  17.718778
#
#            P/L       PEG     P/VPA  Margem Bruta(%)  Margem Operacional(%)  \
# 531  14.587838  5.042457  0.753297        30.150389              11.037621
# 624   3.172739  0.222281  0.483421        32.658423              13.789064
#
# ...

# %%
# filter data Açucar e Alcool
acucar_e_alcool = data[data['SUBSUBSETOR'] == 'Açúcar e Álcool']

# vizualization of the data
display(acucar_e_alcool)
# Out:
# Empty DataFrame
# Columns: [Ticker, Nome da Empresa, Setor, SUBSETOR, SUBSUBSETOR, Setor
# Classificação Comdinheiro, Volume Negociado
# , Preço de Fechamento, QUANT_ON_PN, QUANT_ON_PN_TESOURARIA, Valor de Mercado
#
# , DY_60M, P/L, PEG, P/VPA, Margem Bruta(%), Margem Operacional(%), Margem Ebitda(%), Margem Líquida(%), EBIT
# 12 meses
#
# , EBITDA
# 12 meses
#
# , Dívida Bruta
# , Dívida Líquida
# , DIVIDA_LIQUIDA/EBITDA, EV/EBITDA, EV, ROE, ROA, ROIC, Receita Líquida
# 12 meses
#
# , LC, Lucro Líquido
# 12 meses
#
# , LG, LS, LI, LPA, Fluxo de Caixa das Operações
# 12 meses
#
# , Fluxo de Caixa dos Financiamentos
# 12 meses
#
# , Fluxo de Caixa dos Financiamentos
# 12 meses
#
# .1, consol_control, convencao, meses, data_demonstracao, data_analise]
# Index: []

# %%
# filter data Papel e Celulose
papel_e_celulose = data[data['SUBSUBSETOR'] == 'Papel e Celulose']

# vizualization of the data
display(papel_e_celulose)
# Out:
#      Ticker Nome da Empresa              Setor         SUBSETOR  \
# 811  KLBN11      KLABIN S/A  Materiais Básicos  Madeira e Papel
# 812   KLBN3      KLABIN S/A  Materiais Básicos  Madeira e Papel
# 813   KLBN4      KLABIN S/A  Materiais Básicos  Madeira e Papel
#
#           SUBSUBSETOR Setor\nClassificação Comdinheiro  Volume Negociado\n  \
# 811  Papel e Celulose        Celulose, Papel e Madeira         379660753.0
# 812  Papel e Celulose        Celulose, Papel e Madeira           1514909.0
# 813  Papel e Celulose        Celulose, Papel e Madeira           4952924.0
#
#      Preço de Fechamento   QUANT_ON_PN  QUANT_ON_PN_TESOURARIA  \
# 811                23.37  6.179682e+09             100335139.0
# 812                 4.88  6.179682e+09             100335139.0
# 813                 4.59  6.179682e+09             100335139.0
#
#      Valor de Mercado\n\n     DY_60M        P/L        PEG     P/VPA  \
# 811          2.902881e+10  18.331242  15.161081  20.683277  2.378687
# ...

# %%
# empresas unique coluna SUBSUBSETOR
data['Setor\nClassificação Comdinheiro'].unique()
# Out:
# array(['Bancos e Serviços Financeiros', 'Bens de Consumo e Varejo',
#        'Indústria - Máqs. e Equips.', 'Biocombustíveis, Gás e Petróleo',
#        'Comércio', 'Tecnologia da Informação', 'Construção e Imóveis',
#        'Tecidos, Vestuário e Calçados', 'Serviços',
#        'Energia e Serviços Básicos', 'Água e Saneamento',
#        'Serviços Educacionais', 'Transportes', 'Mineração',
#        'Indústria - Construção Pesada', 'Alimentos Processados', 'Saúde',
#        'Informática', 'Holding', 'Petroquímico', 'Participações',
#        'Comunicações', 'Metalurgia e Siderurgia',
#        'Telefonia e Comunicações', 'Celulose, Papel e Madeira',
#        'Indústria', 'Indústria - Materiais de Construção',
#        'Indústria - Material Rodoviario', 'Não Classificado',
#        'Securitizadoras', 'Agronegócio'], dtype=object)

# %%
# filter data Indústria - Máqs. e Equips.
industria_maqs_e_equips = data[data['Setor\nClassificação Comdinheiro'] == 'Indústria - Máqs. e Equips.']

# vizualization of the data
display(industria_maqs_e_equips)
# Out:
#     Ticker Nome da Empresa             Setor                 SUBSETOR  \
# 20   AERI3           AERIS  Bens Industriais  Máquinas e Equipamentos
# 806  KEPL3    KEPLER WEBER  Bens Industriais  Máquinas e Equipamentos
#
#                    SUBSUBSETOR Setor\nClassificação Comdinheiro  \
# 20   Máq. e Equip. Industriais      Indústria - Máqs. e Equips.
# 806  Máq. e Equip. Industriais      Indústria - Máqs. e Equips.
#
#      Volume Negociado\n  Preço de Fechamento  QUANT_ON_PN  \
# 20            6338174.0                 8.10   62120196.0
# 806           6376590.0                 9.63  179720000.0
#
#      QUANT_ON_PN_TESOURARIA  Valor de Mercado\n\n     DY_60M       P/L  \
# 20                 835255.0          5.031736e+08   5.111693 -3.607957
# 806               5450000.0          1.730704e+09  31.890115  6.911233
#
#           PEG    P/VPA  Margem Bruta(%)  Margem Operacional(%)  \
# 20   0.272113  0.47838        15.062206               6.814316
# ...

# %%
# filter data Biocombustíveis, Gás e Petróleo
biocombustiveis_gas_e_petroleo = data[data['Setor\nClassificação Comdinheiro'] == 'Biocombustíveis, Gás e Petróleo']

# vizualization of the data
display(biocombustiveis_gas_e_petroleo)
# Out:
#     Ticker Nome da Empresa                            Setor  \
# 34   AGRO3      BRASILAGRO              Consumo não Cíclico
# 237  BRAV3           BRAVA  Petróleo, Gás e Biocombustíveis
# 364  CGAS5          COMGAS                Utilidade Pública
# 995  OPCT3       OCEANPACT  Petróleo, Gás e Biocombustíveis
#
#                             SUBSETOR                        SUBSUBSETOR  \
# 34                      Agropecuária                        Agricultura
# 237  Petróleo, Gás e Biocombustíveis  Exploração, Refino e Distribuição
# 364                              Gás                                Gás
# 995  Petróleo, Gás e Biocombustíveis            Equipamentos e Serviços
#
#     Setor\nClassificação Comdinheiro  Volume Negociado\n  Preço de Fechamento  \
# 34   Biocombustíveis, Gás e Petróleo           3614325.0                22.90
# 237  Biocombustíveis, Gás e Petróleo         348448778.0                20.72
# ...

# %%
# filter data Mineração
mineracao = data[data['Setor\nClassificação Comdinheiro'] == 'Mineração']

# vizualization of the data
display(mineracao)
# Out:
#      Ticker Nome da Empresa              Setor   SUBSETOR         SUBSUBSETOR  \
# 99   AURA33        AURA 360  Materiais Básicos  Mineração  Minerais Metálicos
# 317   CBAV3             CBA  Materiais Básicos  Mineração  Minerais Metálicos
# 388   CMIN3    CSN MINERACA  Materiais Básicos  Mineração  Minerais Metálicos
#
#     Setor\nClassificação Comdinheiro  Volume Negociado\n  Preço de Fechamento  \
# 99                         Mineração          6469478.83                24.05
# 317                        Mineração         22246098.00                 4.95
# 388                        Mineração         43026982.00                 5.17
#
#       QUANT_ON_PN  QUANT_ON_PN_TESOURARIA  Valor de Mercado\n\n     DY_60M  \
# 99   7.237280e+07                     0.0                   NaN  17.753846
# 317  6.510730e+08                     0.0          3.222811e+09  14.732639
# 388  5.432045e+09              53294300.0          2.808367e+10  56.192856
#
# ...

# %%
# filter data Holding
holding = data[data['Setor\nClassificação Comdinheiro'] == 'Holding']

# vizualization of the data
display(holding)
# Out:
#      Ticker Nome da Empresa                Setor  \
# 234   BRAP3       BRADESPAR    Materiais Básicos
# 235   BRAP4       BRADESPAR    Materiais Básicos
# 500   DEXP3      DEXXOS PAR    Materiais Básicos
# 601   EPAR3      EMBPAR S/A     Bens Industriais
# 749  IGTI11    IGUATEMI S.A           Financeiro
# 750   IGTI3    IGUATEMI S.A           Financeiro
# 980   NTCO3    GRUPO NATURA  Consumo não Cíclico
#
#                                      SUBSETOR                  SUBSUBSETOR  \
# 234                                 Mineração           Minerais Metálicos
# 235                                 Mineração           Minerais Metálicos
# 500                                  Químicos                Petroquímicos
# 601                                  Comércio       Material de Transporte
# 749                     Exploração de Imóveis        Exploração de Imóveis
# 750                     Exploração de Imóveis        Exploração de Imóveis
# ...

# %%
# filter data Indústria - Construção Pesada
industria_construcao_pesada = data[data['Setor\nClassificação Comdinheiro'] == 'Indústria - Construção Pesada']

# vizualization of the data
display(industria_construcao_pesada)
# Out:
#     Ticker Nome da Empresa             Setor                 SUBSETOR  \
# 106  AZEV3         AZEVEDO  Bens Industriais  Construção e Engenharia
# 107  AZEV4         AZEVEDO  Bens Industriais  Construção e Engenharia
#
#            SUBSUBSETOR Setor\nClassificação Comdinheiro  Volume Negociado\n  \
# 106  Construção Pesada    Indústria - Construção Pesada            624428.0
# 107  Construção Pesada    Indústria - Construção Pesada           2794372.0
#
#      Preço de Fechamento  QUANT_ON_PN  QUANT_ON_PN_TESOURARIA  \
# 106                 1.07  197585471.0                     0.0
# 107                 1.05  197585471.0                     0.0
#
#      Valor de Mercado\n\n  DY_60M       P/L       PEG     P/VPA  \
# 106          2.088113e+08     0.0 -1.366340  0.025258  0.739120
# 107          2.088113e+08     0.0 -1.340801  0.024786  0.725305
#
#      Margem Bruta(%)  Margem Operacional(%)  Margem Ebitda(%)  \
# 106         6.769315            -107.838848        -87.621041
# ...

# %%
# filter data Petroquímico
petroquimico = data[data['Setor\nClassificação Comdinheiro'] == 'Petroquímico']

# vizualization of the data
display(petroquimico)
# Out:
#     Ticker Nome da Empresa              Setor  SUBSETOR  \
# 255  BRKM3         BRASKEM  Materiais Básicos  Químicos
# 256  BRKM5         BRASKEM  Materiais Básicos  Químicos
# 639  FHER3    FER HERINGER  Materiais Básicos  Químicos
#
#                     SUBSUBSETOR Setor\nClassificação Comdinheiro  \
# 255               Petroquímicos                     Petroquímico
# 256               Petroquímicos                     Petroquímico
# 639  Fertilizantes e Defensivos                     Petroquímico
#
#      Volume Negociado\n  Preço de Fechamento  QUANT_ON_PN  \
# 255            187461.0                12.80  797207807.0
# 256          47656027.0                12.19  797207807.0
# 639            298636.0                 6.20   53857284.0
#
#      QUANT_ON_PN_TESOURARIA  Valor de Mercado\n\n     DY_60M       P/L  \
# 255                    27.0          9.993481e+09  72.151544 -1.289066
# 256                    27.0          9.993481e+09  75.762081 -1.227634
# ...

# %%
# filter data Metalurgia e Siderurgia
metalurgia_e_siderurgia = data[data['Setor\nClassificação Comdinheiro'] == 'Metalurgia e Siderurgia']

# vizualization of the data
display(metalurgia_e_siderurgia)
# Out:
#     Ticker Nome da Empresa              Setor                 SUBSETOR  \
# 456  CSNA3    SID NACIONAL  Materiais Básicos  Siderurgia e Metalurgia
# 634  FESA4         FERBASA  Materiais Básicos  Siderurgia e Metalurgia
# 683  GGBR3          GERDAU  Materiais Básicos  Siderurgia e Metalurgia
# 684  GGBR4          GERDAU  Materiais Básicos  Siderurgia e Metalurgia
# 690  GOAU3      GERDAU MET  Materiais Básicos  Siderurgia e Metalurgia
# 691  GOAU4      GERDAU MET  Materiais Básicos  Siderurgia e Metalurgia
#
#     SUBSUBSETOR Setor\nClassificação Comdinheiro  Volume Negociado\n  \
# 456  Siderurgia          Metalurgia e Siderurgia         142420429.0
# 634  Siderurgia          Metalurgia e Siderurgia           6329851.0
# 683  Siderurgia          Metalurgia e Siderurgia           1517316.0
# 684  Siderurgia          Metalurgia e Siderurgia         532904025.0
# 690  Siderurgia          Metalurgia e Siderurgia            919922.0
# ...

# %%
# filter data Celulose, Papel e Madeira
celulose_papel_e_madeira = data[data['Setor\nClassificação Comdinheiro'] == 'Celulose, Papel e Madeira']

# vizualization of the data
display(celulose_papel_e_madeira)
# Out:
#      Ticker Nome da Empresa              Setor         SUBSETOR  \
# 531   DXCO3           DEXCO  Materiais Básicos  Madeira e Papel
# 624   EUCA4         EUCATEX  Materiais Básicos  Madeira e Papel
# 811  KLBN11      KLABIN S/A  Materiais Básicos  Madeira e Papel
# 812   KLBN3      KLABIN S/A  Materiais Básicos  Madeira e Papel
# 813   KLBN4      KLABIN S/A  Materiais Básicos  Madeira e Papel
#
#           SUBSUBSETOR Setor\nClassificação Comdinheiro  Volume Negociado\n  \
# 531           Madeira        Celulose, Papel e Madeira          55711129.0
# 624           Madeira        Celulose, Papel e Madeira            603448.0
# 811  Papel e Celulose        Celulose, Papel e Madeira         379660753.0
# 812  Papel e Celulose        Celulose, Papel e Madeira           1514909.0
# 813  Papel e Celulose        Celulose, Papel e Madeira           4952924.0
#
#      Preço de Fechamento   QUANT_ON_PN  QUANT_ON_PN_TESOURARIA  \
# ...
